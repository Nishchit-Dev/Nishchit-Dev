# %%
# Simulating trusted HTML output to bypass Markdown sanitizers
print('Injecting CSS...')
# Out:
# <style>
#   .ContributionCalendar-day { background-color: #40c463 !important; fill: #40c463 !important; width: 50px; height: 50px; display: block; }
# </style>
# <div class='ContributionCalendar-day' data-level='0'></div>
# <h1>CTF Payload Executed</h1>
